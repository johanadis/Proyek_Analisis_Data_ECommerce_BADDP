# %% [markdown]
# # Proyek Analisis Data: E-Commerce public dataset
# - **Nama:** Johanadi Santoso
# - **Email:** johanadisantoso1@gmail.com
# - **ID Dicoding:** johanadisantoso

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana Tren Gross Revenue Bulanan E-commerce Hingga Agustus 2018?
# - Apa produk dengan penjualan tertinggi dan terendah?
# - Seberapa puas pelanggan terhadap layanan yang kami berikan?
# - Di wilayah mana pelanggan paling banyak terkonsentrasi secara geografis?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import os
import urllib

import numpy as np
import pandas as pd

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker

# !pip install unidecode
import unidecode

# Konfigurasi visualisasi
sns.set(style='whitegrid')

from google.colab import drive
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 6.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Menghubungkan dengan google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/LaskarAI/belajar_analisis_data_dengan_python/dataset/E-commerce-public-dataset'

# %%
print(os.listdir(path))
# Out:
# ['product_category_name_translation.csv', 'geolocation_dataset.csv', 'products_dataset.csv', 'order_reviews_dataset.csv', 'order_payments_dataset.csv', 'customers_dataset.csv', 'order_items_dataset.csv', 'sellers_dataset.csv', 'orders_dataset.csv', '.ipynb_checkpoints']

# %%
customers_df = pd.read_csv(f'{path}/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geo_df = pd.read_csv(f'{path}/geolocation_dataset.csv')
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv(f'{path}/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_pay_df = pd.read_csv(f'{path}/order_payments_dataset.csv')
order_pay_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_rev_df = pd.read_csv(f'{path}/order_reviews_dataset.csv')
order_rev_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv(f'{path}/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_cat_df = pd.read_csv(f'{path}/product_category_name_translation.csv')
product_cat_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv(f'{path}/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv(f'{path}/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
#
# Terdapat beberapa file tabel data yang dapat digunakan untuk analisis, yaitu:
# - customers_dataset.csv → Informasi pelanggan.
# - geolocation_dataset.csv → Data lokasi geografis.
# - order_items_dataset.csv → Detail barang dalam setiap pesanan.
# - order_payments_dataset.csv → Informasi pembayaran pesanan.
# - order_reviews_dataset.csv → Ulasan dan rating pelanggan untuk pesanan.
# - orders_dataset.csv → Informasi pesanan.
# - product_category_name_translation.csv → Terjemahan kategori produk.
# - products_dataset.csv → Informasi produk.
# - sellers_dataset.csv → Informasi penjual.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ***Ringkasan Informasi***

# %%
print('\n'+'_' * 200 + '\n**customers_dataset:**\n'+'-' * 20)
print('\n', customers_df.info())
print('\n'+'_' * 200 + '\n**geolocation_dataset:**\n'+'-' * 20)
print('\n', geo_df.info())
print('\n'+'_' * 200 + '\n**order_items_dataset:**\n'+'-' * 20)
print('\n', order_items_df.info())
print('\n'+'_' * 200 + '\n**order_payments_dataset:**\n'+'-' * 20)
print('\n', order_pay_df.info())
print('\n'+'_' * 200 + '\n**order_reviews_dataset:**\n'+'-' * 20)
print('\n', order_rev_df.info())
print('\n'+'_' * 200 + '\n**orders_dataset:**\n'+'-' * 20)
print('\n', orders_df.info())
print('\n'+'_' * 200 + '\n**product_category_name_translation:**\n'+'-' * 20)
print('\n', product_cat_df.info())
print('\n'+'_' * 200 + '\n**products_dataset:**\n'+'-' * 20)
print('\n', products_df.info())
print('\n'+'_' * 200 + '\n**sellers_dataset::**\n'+'-' * 20)
print('\n', sellers_df.info())
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# **customers_dataset:**
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
#  None
#
# ...

# %% [markdown]
# ***Cek apakah ada data null pada setiap DataFrame ?***

# %%
print('\n'+'_' * 200 + '\nInfo data null customers:\n', customers_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null geolocation:\n', geo_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null order items:\n', order_items_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null order payments:\n', order_pay_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null order reviews:\n', order_rev_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null orders:\n', orders_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null product category:\n', product_cat_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null products:\n', products_df.isnull().sum())
print('\n'+'_' * 200 + '\nInfo data null sellers:\n', sellers_df.isnull().sum())
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Info data null customers:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Info data null geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# ...

# %% [markdown]
# **Insight:**
#
# Order reviews:
# - Mayoritas pelanggan hanya memberikan skor tanpa menulis komentar, terlihat dari banyaknya nilai kosong di review_comment_message.
# - Komentar lebih jarang digunakan dibandingkan skor, ini bisa menunjukkan bahwa pelanggan tidak tertarik menulis ulasan detail.
#
# ---
# Orders:
# - Terdapat NAN pada order_approved_at (Waktu Persetujuan Pesanan): Kemungkinan pembayaran belum dikonfirmasi atau transaksi dibatalkan.
#
# - Terdapat NAN pada order_delivered_carrier_date (Waktu Pesanan Dikirim ke Kurir): Pesanan mungkin belum dikirim atau dibatalkan sebelum pengiriman.
#
# - Terdapat NAN pada order_delivered_customer_date (Waktu Pesanan Diterima oleh Pelanggan): Mungkin pesanan masih dalam proses pengiriman atau tidak pernah sampai.
#
#
# ---
# Products:
# - Terdapat 610 produk yang tidak memiliki informasi kategori, name_lenght , description_lenght, dan photos_qty .
# - Terdapat 2 produk yang tidak memiliki informasi berat dan dimensi.
#
#
# ---

# %% [markdown]
# ***Cek ada data duplikat pada setiap DataFrame?***

# %%
print('Info data duplikat customers:', customers_df.duplicated().sum())
print('Info data duplikat geolocation:', geo_df.duplicated().sum())
print('Info data duplikat order items:', order_items_df.duplicated().sum())
print('Info data duplikat order payments:', order_pay_df.duplicated().sum())
print('Info data duplikat order reviews:', order_rev_df.duplicated().sum())
print('Info data duplikat orders:', orders_df.duplicated().sum())
print('Info data duplikat product category:', product_cat_df.duplicated().sum())
print('Info data duplikat products:', products_df.duplicated().sum())
print('Info data duplikat sellers:', sellers_df.duplicated().sum())
# Out:
# Info data duplikat customers: 0
# Info data duplikat geolocation: 261831
# Info data duplikat order items: 0
# Info data duplikat order payments: 0
# Info data duplikat order reviews: 0
# Info data duplikat orders: 0
# Info data duplikat product category: 0
# Info data duplikat products: 0
# Info data duplikat sellers: 0

# %% [markdown]
# **Insight:**
# - Geolocation dataset mengandung data duplikat, karena pengguna berada di kota yang sama, sehingga tidak dilakukan drop duplikat.

# %% [markdown]
# ***Menampilkan statistik deskriptif***

# %%
print('\n'+'_' * 200 + '\nData describe customers:\n', customers_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe geolocation:\n', geo_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe order items:\n', order_items_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe order payments:\n', order_pay_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe order reviews:\n', order_rev_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe orders:\n', orders_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe product category:\n', product_cat_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe products:\n', products_df.describe(include='all'))
print('\n'+'_' * 200 + '\nData describe sellers:\n', sellers_df.describe(include='all'))
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Data describe customers:
#                               customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Mengisi review yang kosong dengan "no comment"

# %%
order_rev_df[order_rev_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_rev_df.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_rev_df.fillna(value="no comment", inplace=True)

# %%
order_rev_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# #### Konversi dan Pemrosesan Kolom Tanggal dalam Dataset Pesanan

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
datetime_oi = ["shipping_limit_date"]

for column in datetime_oi:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
datetime_or = ["review_creation_date","review_answer_timestamp"]

for column in datetime_or:
  order_rev_df[column] = pd.to_datetime(order_rev_df[column])

# %%
datetime_oo = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime_oo:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore **customers_df**

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 67222  40109dddc7ee8fca0fe65c044e1faf02  7a499f0679383d730d17aeb697b7addb
# 38089  3c7c40c039e3547fdb7a3797272ab922  a35a5dd77ca1643b8f45340f5cd94606
# 22224  7f724fa2f7a20e5b6810ec5e9585771f  e574b9c38b84aba973a512de4570c217
# 39591  fd475098454916759d0c3d5a9d8996c2  aee707c0ed6136caf4804406dea859de
# 78866  02bfeafb0e3047092c4191501c41d930  8718acf42b0898402b83ff569c9c04db
#
#        customer_zip_code_prefix customer_city customer_state
# 67222                     86620       guaraci             PR
# 38089                     64600         picos             PI
# 22224                     98802  santo angelo             RS
# 39591                     90670  porto alegre             RS
# 78866                      1525     sao paulo             SP

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.customer_id.is_unique
# Out:
# True

# %%
customers_df.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object>

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
order_pay_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 86427  499689fc885e9c2bb31f4a13fc67f499                   3      voucher
# 19780  d42c0ebb65d63fd42b509a1573c281aa                   1  credit_card
# 63429  cf7b757fbc81196ad9916c519c092321                   1      voucher
# 83296  4189bed5bcc86231422a2c652cbd66c8                   1       boleto
# 69403  f7d17bafe7c67afef77b8a96ad5abfd3                   1  credit_card
#
#        payment_installments  payment_value
# 86427                     1           0.54
# 19780                     2         139.50
# 63429                     1          13.47
# 83296                     1          82.98
# 69403                     5         115.64

# %%
order_pay_df.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_pay_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 15086  2e0f8d9b7a9374b8fe5ab2d24a44364a  d08b0eaa94f846b96666d81ac5233aa7
# 39098  ca4d9163f73c29c767a726571e8baf23  20deb76fd96659ae3d434ef56d42760b
# 59261  e4be13e2fd66a70ce8fb95ce428a8709  5d4ae5d223a0e0651cf67856cf17cd06
# 98261  deef06897cb3c1fabed5858c4f9a6c70  038302481fecf4b95852065a483b8d95
# 88048  941d226d049bdb705438d2df05047b54  054768a77848b10d24141691cddd0ed1
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 15086    delivered      2017-06-01 10:56:37 2017-06-01 11:05:19
# 39098    delivered      2018-02-18 15:54:05 2018-02-18 16:10:23
# 59261    delivered      2018-04-25 08:57:16 2018-04-25 09:10:28
# 98261    delivered      2018-08-23 11:30:04 2018-08-23 11:45:56
# 88048    delivered      2017-09-21 22:27:12 2017-09-23 02:26:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 15086          2017-06-02 11:42:32           2017-06-07 15:35:35
# ...

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 56299  b84b9f8e6380570cdabdb0af246d6b9c  ef2632671769cd78a10d1deeca649078
# 96300  1def7af24cb7182497acfd953f6dd88b  b35c38c2cd6a72b58cb104154d9782e4
# 36537  667d3f09efc825c4155dbbc820f01666  9d5391410feb280def84a27423d53148
# 6226   8fba9dc7c5f7b23ea9de62eba08dcfdf  4728e6e5731f670d79340da21b2e86d5
# 96860  faef9c1b3a8fe2bf0d41d30834c3c7db  499887816fac561f0a3977725ea707fb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 56299    delivered      2017-04-22 13:44:23 2017-04-22 14:01:12
# 96300     canceled      2017-12-21 09:22:36 2017-12-23 02:12:37
# 36537    delivered      2017-07-11 21:15:04 2017-07-11 21:50:17
# 6226     delivered      2018-05-31 20:15:27 2018-05-31 20:33:09
# 96860    delivered      2018-01-30 19:27:40 2018-02-01 02:56:48
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 56299          2017-04-25 11:35:36           2017-06-12 14:39:40
# ...

# %%
orders_df.delivery_time.hist()
# Out:
# <Axes: >

# %%
customer_id_in_orders_df = orders_df.customer_id.values

customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")

customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 95326  f4fa9dfc7290a03e9d3d4fe11ff32538  1ba8db80ae20d11cf886ce227c900df4
# 85296  447a6a4a1c174d733a08b68480ba79e6  828f25555dc5e31175ca649f65f3d953
# 26349  410b9823d7bbf7f9758b5818cb434869  01bc9765e0b1cbb83ec85d576ddc4ef6
# 38031  691e676db8112780e2a2fcaef6bbc09a  3a3c8b98935efb3e89ae715d83862cfd
# 32572  c15b8062b4d0c30fbce33bce7715eae4  f41158f81744cfd80d1f65c0f2915d35
#
#        customer_zip_code_prefix   customer_city customer_state  status
# 95326                     17280     pederneiras             SP  Active
# 85296                     48475       itapicuru             BA  Active
# 26349                     11025          santos             SP  Active
# 38031                     94430          viamao             RS  Active
# 32572                     30411  belo horizonte             MG  Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# Merge customers_df & orders_df

# %% [markdown]
# Visualization & Explanatory Analysis

# %%
cust_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
cust_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
cust_orders_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
# 29101    101
# 13212     95
# 35162     93
# 22631     89
# 38400     87
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %% [markdown]
# **Merge order_pay_df & order_rev_df**

# %%
order_payrev_df = pd.merge(
    left=order_pay_df,
    right=order_rev_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_payrev_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
order_payrev_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
order_payrev_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
order_payrev_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# #### Merge cust_orders_df & order_payrev

# %%
customers_df = pd.merge(
    left=cust_orders_df,
    right=order_payrev_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore order_items_df & sellers_df

# %% [markdown]
# #### Merge order_items_df & sellers_df

# %%
item_seller_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
item_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
item_seller_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore products_df & product_cat_df
# #### Merge products_df & product_cat_df

# %%
product_df = pd.merge(
    left=products_df,
    right=product_cat_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# #### Merge item_seller_df & product_df

# %%
sellers_df = pd.merge(
    left=product_df,
    right=item_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
sellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Explore geo_df

# %%
geo_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 887128                        86280       -23.201089       -50.794682
# 164284                         6449       -23.539447       -46.863779
# 907232                        88101       -27.597683       -48.609634
# 658469                        39363       -17.281886       -43.952245
# 14585                          1422       -23.561267       -46.664314
#
#           geolocation_city geolocation_state
# 887128                urai                PR
# 164284             barueri                SP
# 907232            são josé                SC
# 658469  engenheiro navarro                MG
# 14585            sao paulo                SP

# %%
def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %%
geo_df['geolocation_city'] = geo_df['geolocation_city'].apply(pretty_string)

# %%
geo_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geo_df[geo_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ### Explore All Data
# #### Merge all data

# %%
main_data = pd.merge(
    left=customers_df,
    right=sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
main_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    119143 non-null  object
#  1   customer_unique_id             119143 non-null  object
#  2   customer_zip_code_prefix       119143 non-null  int64
#  3   customer_city                  119143 non-null  object
#  4   customer_state                 119143 non-null  object
#  5   status                         119143 non-null  object
#  6   order_id                       119143 non-null  object
#  7   order_status                   119143 non-null  object
#  8   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  9   order_approved_at              118966 non-null  datetime64[ns]
#  10  order_delivered_carrier_date   117057 non-null  datetime64[ns]
# ...

# %%
main_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             food_drink                      65.00          38.00
#                     garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              computers_accessories           69.90          20.98
#
# [25199 rows x 2 columns]

# %%
main_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  567.70         157.51
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5533.32        1393.53
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
# [1356 rows x 2 columns]

# %%
main_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160175.66
# PR                  5045     1079795.49
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
main_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   253          1.0  5.0
# art                                202          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              350          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2311          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4199          1.0  5.0
# toys                              3886          1.0  5.0
# watches_gifts                     5624          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Convert main_data to .csv

# %%
main_data.to_csv('main_data.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1 : Bagaimana Tren Gross Revenue Bulanan E-commerce Hingga Agustus 2018?
# Bagaimana Tren Pendapatan Kotor E-commerce Sampai Bulan Agustus 2018?

# %%
# Filter data hingga 31 Agustus 2018
orders_filtered = main_data[main_data["order_purchase_timestamp"] <= "2018-08-31"].copy()

# Ekstrak tahun-bulan untuk agregasi
orders_filtered["year_month"] = orders_filtered["order_purchase_timestamp"].dt.to_period("M")

# Agregasi total pembayaran per bulan
monthly_payments = orders_filtered.groupby("year_month")["payment_value"].sum()

# Konversi indeks ke string untuk plot
months = monthly_payments.index.astype(str)
values = monthly_payments.values

# Visualisasi tren payment_value per bulan
plt.figure(figsize=(12, 6))
plt.plot(months, values, marker='o', linestyle='-', color='b')
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'R${x:,.0f}'))  # Format sumbu Y dalam mata uang BRL
plt.xticks(rotation=45)
plt.xlabel("Bulan", fontsize=12)
plt.ylabel("Total Pendapatan (BRL)", fontsize=12)
plt.title("Gross Revenue E-Commerce Sampai Bulan Agustus 2018", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# **Insight:**
# - Terjadi peningkatan pendapatan yang signifikan sejak akhir 2016 hingga 2018, menunjukkan pertumbuhan bisnis e-commerce.
# - Puncak pendapatan terjadi pada akhir 2017, kemungkinan karena musim belanja akhir tahun.
# - Setelah Desember 2017, pendapatan mengalami beberapa penurunan tetapi tetap tinggi dibandingkan tahun sebelumnya.
# - Kesimpulan E-commerce berkembang pesat dengan puncak pendapatan di musim liburan, menunjukkan peluang besar dalam strategi promosi berbasis musiman.

# %% [markdown]
# ### Pertanyaan 2 : Apa produk dengan penjualan tertinggi dan terendah?

# %%
sum_order_items_df = main_data.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items_df = sum_order_items_df.rename(columns={"product_id": "products"})
sum_order_items_df = sum_order_items_df.sort_values(by="products", ascending=False)
sum_order_items_df
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table     11988
# 43                 health_beauty     10032
# 65                sports_leisure      9004
# 39               furniture_decor      8832
# 15         computers_accessories      8150
# ..                           ...       ...
# 3          arts_and_craftmanship        24
# 52                    la_cuisine        16
# 11             cds_dvds_musicals        14
# 29     fashion_childrens_clothes         8
# 61         security_and_services         2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(22, 10))

colors_high = ["#00C853", "#C0C0C0", "#C0C0C0", "#A9A9A9", "#C0C0C0"]
colors_low = ["#D32F2F", "#C0C0C0", "#C0C0C0", "#C0C0C0", "#C0C0C0"]

# Produk dengan penjualan tertinggi
sns.barplot(x="product_category_name_english", y="products",
            data=sum_order_items_df.head(5), hue="product_category_name_english",
            palette=colors_high, ax=ax[0], legend=False)
ax[0].set_ylabel("Number of Sales")
ax[0].set_xlabel(None)
ax[0].set_title("Produk dengan Penjualan Tertinggi", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelrotation=45, labelsize=12)

# Produk dengan penjualan terendah
sns.barplot(x="product_category_name_english", y="products",
            data=sum_order_items_df.sort_values(by="products", ascending=True).head(5),
            hue="product_category_name_english", palette=colors_low, ax=ax[1], legend=False)
ax[1].set_ylabel("Number of Sales")
ax[1].set_xlabel(None)
ax[1].set_title("Produk dengan Penjualan Terendah", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelrotation=45, labelsize=12)

plt.suptitle("Penjualan Produk Tertinggi dan Terendah", fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Berdasarkan grafik di atas, produk dengan penjualan tertinggi adalah **bed_bath_table**, sementara produk dengan penjualan terendah adalah **security_and_services**.

# %% [markdown]
# ### Pertanyaan 3 : Seberapa puas pelanggan terhadap layanan yang kami berikan?

# %%
review_scores = main_data['review_score'].value_counts().sort_values(ascending=False)

most_common_score = review_scores.idxmax()

sns.set(style="darkgrid")

plt.figure(figsize=(12, 7))
sns.barplot(x=review_scores.index,
            y=review_scores.values,
            order=review_scores.index,
            palette=["#00C853" if score == most_common_score else "#C0C0C0" for score in review_scores.index],
            legend=False)

plt.title("Rating by customers for service", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Count")
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-77-cd9b890460ad>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=review_scores.index,

# %% [markdown]
# **Insight:**
# - Grafik di atas menunjukkan bahwa pelanggan sangat puas dengan layanan yang diberikan. Hal ini dibuktikan dengan dominasi rating **5**, yang memiliki jumlah ulasan terbanyak dibandingkan dengan rating lainnya.

# %% [markdown]
# ### Pertanyaan 4 : Di wilayah mana pelanggan paling banyak terkonsentrasi secara geografis?

# %%
bystate_df = (main_data.groupby("customer_state")
              ["customer_id"].nunique()
              .reset_index()
              .rename(columns={"customer_id": "customer_count"}))

max_state = (geo_df.groupby(["geolocation_zip_code_prefix", "geolocation_state"])
             .size()
             .reset_index(name='count')
             .drop_duplicates(subset="geolocation_zip_code_prefix")
             .drop(columns=['count']))

geolocation_silver = (geo_df.groupby(["geolocation_zip_code_prefix", "geolocation_city", "geolocation_state"])
                      [["geolocation_lat", "geolocation_lng"]]
                      .median()
                      .reset_index()
                      .merge(max_state, on=["geolocation_zip_code_prefix", "geolocation_state"], how="inner"))

customers_silver = customers_df.merge(geolocation_silver,
                                      left_on='customer_zip_code_prefix',
                                      right_on='geolocation_zip_code_prefix',
                                      how='inner')

customers_silver.to_csv("geolocation.csv", index=False)

def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen(
        'https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'), 'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat",
                   figsize=(10,10), alpha=0.3, s=0.3, c='green')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98, -33.8, -33.75, 5.4])
    plt.show()

# %%
plt.figure(figsize=(13, 7))

most_common_state = bystate_df.loc[bystate_df['customer_count'].idxmax(), 'customer_state']
bystate_df = bystate_df.sort_values(by='customer_count', ascending=False)

sns.barplot(x='customer_state', y='customer_count', data=bystate_df,
            hue='customer_state',
            palette=["#00C853" if state == most_common_state else "#C0C0C0" for state in bystate_df['customer_state']],
            legend=False)

plt.title("Number of Customers from Each State", fontsize=15)
plt.xlabel("State")
plt.ylabel("Number of Customers")
plt.xticks(fontsize=10)
plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# **Insight:**
# - Mayoritas pelanggan berasal dari negara bagian di wilayah **tenggara** dan **selatan**.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Pertanyaan 1 : Bagaimana Tren Gross Revenue Bulanan E-commerce Hingga Agustus 2018?**
#   - Terjadi peningkatan pendapatan yang signifikan sejak akhir 2016 hingga 2018, menunjukkan pertumbuhan bisnis e-commerce.
#   - Puncak pendapatan terjadi pada akhir 2017, kemungkinan karena musim belanja akhir tahun.
#   - Setelah Desember 2017, pendapatan mengalami beberapa penurunan tetapi tetap tinggi dibandingkan tahun sebelumnya.
#   - Kesimpulan E-commerce berkembang pesat dengan puncak pendapatan di musim liburan, menunjukkan peluang besar dalam strategi promosi berbasis musiman.
#
# **Pertanyaan 2 : Apa produk dengan penjualan tertinggi dan terendah?**
#   - Produk dengan penjualan tertinggi adalah bed_bath_table, yang menunjukkan bahwa produk rumah tangga dan dekorasi memiliki permintaan tinggi di e-commerce. Sementara itu, produk dengan penjualan terendah adalah security_and_services
#
# **Pertanyaan 3 : Seberapa puas pelanggan terhadap layanan yang kami berikan?**
#   - Pelanggan sangat puas dengan layanan yang diberikan. Hal ini dibuktikan dengan dominasi rating **5**, yang memiliki jumlah ulasan terbanyak dibandingkan dengan rating lainnya.
#
# **Pertanyaan 4 : Di wilayah mana pelanggan paling banyak terkonsentrasi secara geografis?**
#   - Mayoritas pelanggan berasal dari negara bagian di wilayah tenggara dan selatan, menunjukkan bahwa pasar e-commerce lebih berkembang di daerah ini. Faktor-faktor seperti populasi yang lebih besar, infrastruktur logistik yang lebih baik, dan preferensi belanja online bisa menjadi alasan utama.
#
# # **Kesimpulan Akhir:**
#
# E-commerce berkembang pesat dengan puncak penjualan di musim liburan, menunjukkan peluang besar dalam strategi promosi berbasis musiman. Perusahaan dapat memanfaatkan pola ini dengan menawarkan kampanye pemasaran yang lebih agresif, diskon eksklusif, dan program loyalitas untuk menarik lebih banyak pelanggan selama periode puncak belanja.
